# %% [markdown]
# **Diana Laura Equihua Díaz**
# 19020088
# Inteligencia Artificial

# %% [markdown]
# ## ML - Algoritmos de Clasificación

# %% [markdown]
# ### Regresión Logística

# %% [markdown]
# **Conjunto de datos iris**
# El cual es un conjunto de datos introducido por Ronald Fisher, en el se encuentran contenidas 50 muestras de cada una de las especies de iris (iris setosa, iris virginica, iris versicolor). Se midió 4 rasgos de cada muestra: lo largo y lo ancho de los sépalos y pétalos, en centímetros.

# %% [markdown]
# - Como primer paso a realizar, es la importación de las librerias que se necesitan

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %% [markdown]
# - Despues se carga el conjunto de datos de iris a una variable con el mismo nombre y se imprime para saber los datos que contienen.

# %%
iris= load_iris()
iris

# %% [markdown]
# -Una vez cargado los datos a una variable, lo que se realizará es separar el data con el target del conjunto de datos de iris. Didiendo en dos variables X, y, donde:
# La varible X tiene los datos
# La variable y tiene una de las caracteristicas del conjunto de datos, osea que identifica la especie de iris, la cual son tres distintos.
#
# Una vez realizado esto, se utilizará scatter para poder graficar el conjunto de datos de la variable X que son tanto el ancho y largo del sepalo, el tercer parametro se define el color con el objetivo de identificar que tipo de iris es y el ultimo parametro es la apariencia que tendrá la grafica.

# %%
X = iris.data[:,:2]
y =iris.target

plt.scatter(X[:,0], X[:,1], c=y, cmap="viridis")
plt.xlabel("Largo del Sepalo")
plt.ylabel("Ancho del Sepalo")
plt.title("Conjunto de datos del iris")
plt.show()

# %% [markdown]
# - Lo siguiente que se realizará es definir las variables de entrenamiento(train y test)

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.data,iris.target,test_size=0.3,random_state=42)

# %% [markdown]
# -  Se define el modelo de regresión logistica, donde se le da la propiedad de ser multiclase y la manera en que va a hacer optimizado

# %%
lr=LogisticRegression(multi_class="multinomial", solver="lbfgs")

# %% [markdown]
# - Se entrena el modelo lr con el conjunto de datos de entrenamiento X_train y y_train

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(multi_class='multinomial')

# %% [markdown]
# - Se crea una variable de prediccion y se le manda como parametro la variable de prueba X_test, la cual va a predecir que tipo de iris es.

# %%
y_pred = lr.predict(X_test)

# %% [markdown]
# - Con la variable de accurancy permitira saber el porcentaje de predicciones correctas que realiza el modelo que se creo anteriormente.

# %%
accuracy = accuracy_score(y_test,y_pred)
print("El accuracy es =", accuracy)
# Out:
# El accuracy es = 1.0

# %% [markdown]
# - Para realizar las predicciones del modelo, se le da datos sobre las caracteristicas del iris. Tiendo los datos de :
# * Largo del Sepalo
# * Ancho del Sepalo
# * Largo del Petalo
# * Ancho del Petalo
#
# Los datos de salida son 0, 1 y 2, donde:
# * *0* es el tipo de iris setosa
# * *1* es el tipo de iris versicolor
# * *2* es el tipo de iris virginica

# %%
data1=[[1.1,1.5,3.4,0.2]]
data2=[[2.1,1.5,3.5,4.2]]

prediccion1= lr.predict(data1)
prediccion2= lr.predict(data2)

print("Prediccion 1 es: ", prediccion1)
print("Prediccion 2 es:", prediccion2)
# Out:
# Prediccion 1 es:  [0]
# Prediccion 2 es: [2]

# %% [markdown]
# -  Las predicciones que se realizaron fueron:
#   * La prediccion 1 dice que es un tipo de iris setosa
#   * La prediccion 2 dice que es un tipo de iris virginica

# %% [markdown]
# ### Árboles de Decisión
